# %%
import pandas as pd
import seaborn as sb

filepath_cereal = "/Users/abdullahkhan/MathMethodsforDA/MathematicalMethods/Assignment1/F1DataSet/cereal.csv"
cereal = pd.read_csv(filepath_cereal)
pd.set_option('precision', 3)

# %%
cer = cereal.tail(60)
cer
# Out:
#                                       name mfr type  calories  protein  fat  \
# 17                               Corn Pops   K    C       110        1    0
# 18                           Count Chocula   G    C       110        1    1
# 19                      Cracklin' Oat Bran   K    C       110        3    3
# 20                  Cream of Wheat (Quick)   N    H       100        3    0
# 21                                 Crispix   K    C       110        2    0
# 22                  Crispy Wheat & Raisins   G    C       100        2    1
# 23                             Double Chex   R    C       100        2    0
# 24                             Froot Loops   K    C       110        2    1
# 25                          Frosted Flakes   K    C       110        1    0
# 26                     Frosted Mini-Wheats   K    C       100        3    0
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# ...

# %%
cer.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
cer.ndim
# Out:
# 2

# %%
cer.shape
# Out:
# (60, 16)

# %%
cer.describe()
# Out:
#        calories  protein     fat   sodium   fiber   carbo  sugars   potass  \
# count    60.000   60.000  60.000   60.000  60.000  60.000  60.000   60.000
# mean    108.333    2.517   0.900  150.250   1.853  15.075   6.933   90.233
# std      18.881    1.033   0.877   85.487   1.557   4.068   4.584   58.636
# min      50.000    1.000   0.000    0.000   0.000  -1.000  -1.000   -1.000
# 25%     100.000    2.000   0.000   93.750   0.750  12.750   3.000   40.000
# 50%     110.000    3.000   1.000  170.000   1.750  15.000   6.500   90.000
# 75%     110.000    3.000   1.000  202.500   3.000  17.000  11.000  116.250
# max     160.000    6.000   3.000  320.000   6.000  23.000  15.000  260.000
#
#        vitamins   shelf  weight    cups  rating
# count    60.000  60.000  60.000  60.000  60.000
# mean     29.583   2.217   1.032   0.837  42.569
# std      24.996   0.825   0.166   0.225  12.519
# min       0.000   1.000   0.500   0.250  21.871
# 25%      25.000   1.750   1.000   0.670  33.657
# ...

# %%
(cer.rating > 40.277).describe()
# Out:
# count       60
# unique       2
# top       True
# freq        30
# Name: rating, dtype: object

# %%
# %matplotlib inline

# %%
histogram = cer.hist('rating')

# %%
histogram = cer.hist('calories')
