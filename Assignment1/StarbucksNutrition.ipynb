# %%
import pandas as pd

filepath_nutrition = "/Users/abdullahkhan/MathMethodsforDA/MathematicalMethods/Assignment1/StarbucksData/starbucks_drinkMenu_expanded.csv"
nutrition = pd.read_csv(filepath_nutrition)
pd.set_option('precision', 3)

# %%
nutrition_slice = nutrition.head(60)
nutrition_slice.columns = ['BeverageCategory', 'Beverage', 'BeveragePrep', 'Calories', 'TotalFat', 'TransFat', 'SaturatedFat', 'Sodium', 'TotalCarbohydrates', 'Cholesterol', 'DietaryFibre', 'Sugars', 'Protein', 'VitaminA', 'VitaminC', 'Calcium', 'Iron', 'Caffeine']
nutrition_slice
# Out:
#            BeverageCategory                                  Beverage  \
# 0                    Coffee                             Brewed Coffee
# 1                    Coffee                             Brewed Coffee
# 2                    Coffee                             Brewed Coffee
# 3                    Coffee                             Brewed Coffee
# 4   Classic Espresso Drinks                               Caffè Latte
# 5   Classic Espresso Drinks                               Caffè Latte
# 6   Classic Espresso Drinks                               Caffè Latte
# 7   Classic Espresso Drinks                               Caffè Latte
# 8   Classic Espresso Drinks                               Caffè Latte
# 9   Classic Espresso Drinks                               Caffè Latte
# 10  Classic Espresso Drinks                               Caffè Latte
# 11  Classic Espresso Drinks                               Caffè Latte
# ...

# %%
nutrition_slice.dtypes
# Out:
# BeverageCategory       object
# Beverage               object
# BeveragePrep           object
# Calories                int64
# TotalFat               object
# TransFat              float64
# SaturatedFat          float64
# Sodium                  int64
# TotalCarbohydrates      int64
# Cholesterol             int64
# DietaryFibre            int64
# Sugars                  int64
# Protein               float64
# VitaminA               object
# VitaminC               object
# Calcium                object
# Iron                   object
# Caffeine               object
# dtype: object

# %%
nutrition_slice.ndim
# Out:
# 2

# %%
nutrition_slice.shape
# Out:
# (60, 18)

# %%
nutrition_slice.Caffeine.describe()
# Out:
# count     60
# unique    11
# top       75
# freq      22
# Name: Caffeine, dtype: object

# %%
# %matplotlib inline

# %%
histogram = nutrition_slice.hist('Cholesterol')
