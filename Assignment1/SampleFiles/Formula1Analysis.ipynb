# %%
import pandas as pd

filepath_circuits = "/Users/abdullahkhan/MathMethodsforDA/MathematicalMethods/Assignment1/F1DataSet/circuits.csv"
circuits = pd.read_csv(filepath_circuits)

# %%
circuits
# Out:
#     circuitId     circuitRef                                  name  \
# 0           1    albert_park        Albert Park Grand Prix Circuit
# 1           2         sepang          Sepang International Circuit
# 2           3        bahrain         Bahrain International Circuit
# 3           4      catalunya        Circuit de Barcelona-Catalunya
# 4           5       istanbul                         Istanbul Park
# ..        ...            ...                                   ...
# 71         72  port_imperial          Port Imperial Street Circuit
# 72         73            BAK                     Baku City Circuit
# 73         74          hanoi                  Hanoi Street Circuit
# 74         75       portimao    Autódromo Internacional do Algarve
# 75         76        mugello  Autodromo Internazionale del Mugello
#
#         location     country       lat        lng alt  \
# 0      Melbourne   Australia -37.84970  144.96800  10
# ...

# %%
circuits.head(60)
# Out:
#     circuitId      circuitRef                                   name  \
# 0           1     albert_park         Albert Park Grand Prix Circuit
# 1           2          sepang           Sepang International Circuit
# 2           3         bahrain          Bahrain International Circuit
# 3           4       catalunya         Circuit de Barcelona-Catalunya
# 4           5        istanbul                          Istanbul Park
# 5           6          monaco                      Circuit de Monaco
# 6           7      villeneuve              Circuit Gilles Villeneuve
# 7           8     magny_cours          Circuit de Nevers Magny-Cours
# 8           9     silverstone                    Silverstone Circuit
# 9          10  hockenheimring                         Hockenheimring
# 10         11     hungaroring                            Hungaroring
# 11         12        valencia                Valencia Street Circuit
# 12         13             spa           Circuit de Spa-Francorchamps
# ...

# %%
circuits
# Out:
#     circuitId     circuitRef                                  name  \
# 0           1    albert_park        Albert Park Grand Prix Circuit
# 1           2         sepang          Sepang International Circuit
# 2           3        bahrain         Bahrain International Circuit
# 3           4      catalunya        Circuit de Barcelona-Catalunya
# 4           5       istanbul                         Istanbul Park
# ..        ...            ...                                   ...
# 71         72  port_imperial          Port Imperial Street Circuit
# 72         73            BAK                     Baku City Circuit
# 73         74          hanoi                  Hanoi Street Circuit
# 74         75       portimao    Autódromo Internacional do Algarve
# 75         76        mugello  Autodromo Internazionale del Mugello
#
#         location     country       lat        lng alt  \
# 0      Melbourne   Australia -37.84970  144.96800  10
# ...

# %%
circuits.ndim
# Out:
# 2

# %%
circuits.shape
# Out:
# (76, 9)

# %%
circuits.dtypes
# Out:
# circuitId       int64
# circuitRef     object
# name           object
# location       object
# country        object
# lat           float64
# lng           float64
# alt            object
# url            object
# dtype: object
