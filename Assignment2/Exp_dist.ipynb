# %% [markdown]
# ## Exponentially distributed random values

# %% [markdown]
# ### Setting up exponential values

# %%
final_exp = []
uniform_values = [random.expovariate(0.08)
                          for _ in range(10000)] # Sigma = 1/desired mean = 1/12.5 = 0.08

# %% [markdown]
# ### Placing data into NumPy Array & ensuring data range of [0,25]

# %%
for x in uniform_values:
    if x >= 0 and x<=25:
        final_exp.append(x)
        
values, frequencies = np.unique(final_exp, return_counts='TRUE')
len(final_exp)
# Out:
# 8616

# %% [markdown]
# ### Plotting data

# %%
# %matplotlib inline
sns.set_style('darkgrid')
sns.set_context('talk')
axes = sns.distplot(values, bins=25, color='green')
axes.set_title('Exponential Distributed Random Values')
axes.set_xlabel('Number')
axes.set_ylabel('Probability Density')
#linplt = sns.lineplot(x=values, y=frequencies, color = 'red')
# Out:
# Text(0, 0.5, 'Probability Density')
