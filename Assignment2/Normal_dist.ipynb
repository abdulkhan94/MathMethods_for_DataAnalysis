# %% [markdown]
# # Normal Distributed Random Values

# %%
import numpy as np
import random
import seaborn as sns

# %% [markdown]
# ### Setting up normal values

# %%
final_normal = []
normal_values = [random.normalvariate(12.5, 4)
                          for _ in range(10000)]

# %% [markdown]
# ### Placing data into NumPy Array & ensuring data range of [0,25]

# %%
for x in normal_values: 
    if x >= 0 and x< 26:
        final_normal.append(x)
        
values, frequencies = np.unique(final_normal, return_counts='TRUE')
stdev = np.std(final_normal)
len(final_normal)
# Out:
# 9992

# %% [markdown]
# ### Checking mean for the dataset

# %%
nmean = np.mean(final_normal)
nmean
# Out:
# 12.462527247007483

# %% [markdown]
# ### Plotting Data

# %%
# %matplotlib inline
sns.set_style('whitegrid')
axes = sns.distplot(values, bins= 20, color = 'blue')
axes.set_title('Normalized Distributed Random Values')
axes.set_xlabel('Number')
axes.set_ylabel('Normalized Count')
#linplt = sns.lineplot(x=values, y=frequencies, color = 'red')
# Out:
# Text(0, 0.5, 'Normalized Count')
