# %% [markdown]
# ## Uniformly Distributed Random Values

# %%
import numpy as np
import random
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setting up uniform values

# %%
final_uniform = []
uniform_values = [random.uniform(0, 25) 
                          for _ in range(100000)]

# %% [markdown]
# ### Placing data into NumPy Array & ensuring data range of [0,25]

# %%
for x in uniform_values: #Ensuring all values are in range 0-25 inclusive
    if x >= 0 and x<= 25:
        final_uniform.append(x) 

values, frequencies = np.unique(final_uniform, return_counts='TRUE')
np.mean(final_uniform) #Checking mean
# Out:
# 12.507527227962898

# %% [markdown]
# ### Plotting Data

# %%
# %matplotlib inline
plt.style.use('Solarize_Light2')
axes = sns.distplot(values, bins= 25, color = 'blue')
#linplt = sns.lineplot(x=values, y=frequencies, color = 'red')
axes.set_title('Uniformly Distributed Random Values')
axes.set_xlabel('Number')
axes.set_ylabel('Normalized Frequency')
# Out:
# Text(0, 0.5, 'Normalized Frequency')
